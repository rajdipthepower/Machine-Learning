# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np

# %%
df=pd.read_csv("canada_per_capita_income.csv", header=0,names = ["year","Income"])
df
# Out:
#     year        Income
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
plt.scatter(df.year,df.Income,color='red',marker="+")
plt.xlabel("Years")
plt.ylabel("Per capita income in $")
plt.plot(years,predictions)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 plt.xlabel("Years")
#       3 plt.ylabel("Per capita income in $")
# ----> 4 plt.plot(years,predictions)
#       5 plt.show()
#
# NameError: name 'years' is not defined

# %%
years=df.drop("Income",axis="columns")
print(years.to_string(index=False))
# Out:
#  year
#  1970
#  1971
#  1972
#  1973
#  1974
#  1975
#  1976
#  1977
#  1978
#  1979
#  1980
#  1981
#  1982
#  1983
#  1984
#  1985
#  1986
#  1987
#  1988
#  1989
#  1990
#  1991
#  1992
#  1993
#  1994
#  1995
#  1996
#  1997
#  1998
#  1999
#  2000
#  2001
#  2002
#  2003
#  2004
#  2005
#  2006
#  2007
#  2008
#  2009
#  2010
#  2011
#  2012
#  2013
#  2014
#  2015
#  2016

# %%
income=df[["Income"]]
print(income.to_string(index=False))
# Out:
#       Income
#  3399.299037
#  3768.297935
#  4251.175484
#  4804.463248
#  5576.514583
#  5998.144346
#  7062.131392
#  7100.126170
#  7247.967035
#  7602.912681
#  8355.968120
#  9434.390652
#  9619.438377
# 10416.536590
# 10790.328720
# 11018.955850
# 11482.891530
# 12974.806620
# 15080.283450
# 16426.725480
# 16838.673200
# 17266.097690
# 16412.083090
# 15875.586730
# 15755.820270
# 16369.317250
# 16699.826680
# 17310.757750
# 16622.671870
# 17581.024140
# 18987.382410
# 18601.397240
# 19232.175560
# 22739.426280
# 25719.147150
# 29198.055690
# 32738.262900
# 36144.481220
# 37446.486090
# 32755.176820
# 38420.522890
# 42334.711210
# 42665.255970
# 42676.468370
# 41039.893600
# 35175.188980
# 34229.193630

# %%
model=linear_model.LinearRegression()
model.fit(years,income)
# Out:
# LinearRegression()

# %%
model.predict([[2015]])[0][0]
# Out:
# C:\Users\user\Desktop\ML Project\ml\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(37146.36871830397)

# %%
model.score(years,income)
# Out:
# 0.8888535970436545

# %%
print("the weight is ",model.coef_[0][0])
# Out:
# the weight is  828.4650752227104

# %%
print("The bias is",model.intercept_[0])
# Out:
# The bias is -1632210.7578554575

# %%
2015*838.70814393-1652707.1383370224
# Out:
# 37289.77168192761

# %%
predictions=model.predict(years)

# %%
plt.plot(years,predictions)
